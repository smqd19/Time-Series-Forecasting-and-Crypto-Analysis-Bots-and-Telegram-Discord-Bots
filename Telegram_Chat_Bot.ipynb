# %%
import pandas as pd, tkinter as tk
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk

class NewWindow1(Toplevel):
    
    def send_message(self, j,k,l,m,n,a,b,c,d,e,f,g,h):
        print("Chat/Group Link 1:",j)
        print("Chat/Group Link 2:",k)
        print("Chat/Group Link 3:",l)
        print("Chat/Group Link 4:",m)
        print("Chat/Group Link 5:",n)
        print("Super User:",a)
        print("Client1:",b)
        print("Client2:",c)
        print("Client3:",d)
        print("Client4:",e)
        print("Client5:",f)
        print("Client6:",g)
        print("Time Delay:",h)

    def __init__(self, master):
        super().__init__(master=master)
        l9 = Label(self, text='Group/Channel Link 1')
        l9.pack()
        self.e8 = Entry(self)
        self.e8.pack(fill='x')
        self.e8.focus_set()
        l10 = Label(self, text='Group/Channel Link 2')
        l10.pack()
        self.e9 = Entry(self)
        self.e9.pack(fill='x')
        self.e9.focus_set()
        l13 = Label(self, text='Group/Channel Link 3')
        l13.pack()
        self.e10 = Entry(self)
        self.e10.pack(fill='x')
        self.e10.focus_set()
        l14 = Label(self, text='Group/Channel Link 4')
        l14.pack()
        self.e11 = Entry(self)
        self.e11.pack(fill='x')
        self.e11.focus_set()
        
        l15 = Label(self, text='Group/Channel Link 5')
        l15.pack()
        self.e12 = Entry(self)
        self.e12.pack(fill='x')
        self.e12.focus_set()
        l1 = Label(self, text='Zeeshan Message')
        l1.pack()
        self.title('Telegram Bot')
        self.geometry('550x600')
        self.e = Entry(self)
        self.e.pack(fill='x')
        self.e.focus_set()
        l2 = Label(self, text='Chris Message')
        l2.pack()
        self.e1 = Entry(self)
        self.e1.pack(fill='x')
        self.e1.focus_set()
        l3 = Label(self, text='Reddit_Promoter Message')
        l3.pack()
        self.e2 = Entry(self)
        self.e2.pack(fill='x')
        self.e2.focus_set()
        l4 = Label(self, text='Simon Message')
        l4.pack()
        self.e3 = Entry(self)
        self.e3.pack(fill='x')
        self.e3.focus_set()
        l5 = Label(self, text='John Message')
        l5.pack()
        self.e4 = Entry(self)
        self.e4.pack(fill='x')
        self.e4.focus_set()
        l6 = Label(self, text='Franklin Message')
        l6.pack()
        self.e5 = Entry(self)
        self.e5.pack(fill='x')
        self.e5.focus_set()
        l7 = Label(self, text='Jordan Message')
        l7.pack()
        self.e6 = Entry(self)
        self.e6.pack(fill='x')
        self.e6.focus_set()
        l8 = Label(self, text='Time Delay Seconds')
        l8.pack()
        self.e7 = Entry(self)
        self.e7.pack(fill='x')
        self.e7.focus_set()
        self.b = Button(self, text='Send Messages')
        self.b.bind('<Button>', lambda e: self.send_message(self.e8.get(), self.e9.get(), self.e10.get(), self.e11.get(), self.e12.get(), self.e.get(), self.e1.get(), self.e2.get(), self.e3.get(), self.e4.get(), self.e5.get(), self.e6.get(),self.e7.get()))
        self.b.pack(side='bottom', pady=10)
        self.mainloop()

        
class NewWindow1(Toplevel):
    
    def send_message(self, j,k,l,m,n,a,b,c,d,e,f,g,h):
        print("Chat/Group Link 1:",j)
        print("Chat/Group Link 2:",k)
        print("Chat/Group Link 3:",l)
        print("Chat/Group Link 4:",m)
        print("Chat/Group Link 5:",n)
        print("Super User:",a)
        print("Client1:",b)
        print("Client2:",c)
        print("Client3:",d)
        print("Client4:",e)
        print("Client5:",f)
        print("Client6:",g)
        print("Time Delay:",h)

    def __init__(self, master):
        super().__init__(master=master)
        l9 = Label(self, text='Group/Channel Link 1')
        l9.pack()
        self.e8 = Entry(self)
        self.e8.pack(fill='x')
        self.e8.focus_set()
        l10 = Label(self, text='Group/Channel Link 2')
        l10.pack()
        self.e9 = Entry(self)
        self.e9.pack(fill='x')
        self.e9.focus_set()
        l13 = Label(self, text='Group/Channel Link 3')
        l13.pack()
        self.e10 = Entry(self)
        self.e10.pack(fill='x')
        self.e10.focus_set()
        l14 = Label(self, text='Group/Channel Link 4')
        l14.pack()
        self.e11 = Entry(self)
        self.e11.pack(fill='x')
        self.e11.focus_set()
        
        l15 = Label(self, text='Group/Channel Link 5')
        l15.pack()
        self.e12 = Entry(self)
        self.e12.pack(fill='x')
        self.e12.focus_set()
        l1 = Label(self, text='Zeeshan Message')
        l1.pack()
        self.title('Telegram Bot')
        self.geometry('550x600')
        self.e = Entry(self)
        self.e.pack(fill='x')
        self.e.focus_set()
        l2 = Label(self, text='Chris Message')
        l2.pack()
        self.e1 = Entry(self)
        self.e1.pack(fill='x')
        self.e1.focus_set()
        l3 = Label(self, text='Reddit_Promoter Message')
        l3.pack()
        self.e2 = Entry(self)
        self.e2.pack(fill='x')
        self.e2.focus_set()
        l4 = Label(self, text='Simon Message')
        l4.pack()
        self.e3 = Entry(self)
        self.e3.pack(fill='x')
        self.e3.focus_set()
        l5 = Label(self, text='John Message')
        l5.pack()
        self.e4 = Entry(self)
        self.e4.pack(fill='x')
        self.e4.focus_set()
        l6 = Label(self, text='Franklin Message')
        l6.pack()
        self.e5 = Entry(self)
        self.e5.pack(fill='x')
        self.e5.focus_set()
        l7 = Label(self, text='Jordan Message')
        l7.pack()
        self.e6 = Entry(self)
        self.e6.pack(fill='x')
        self.e6.focus_set()
        l8 = Label(self, text='Time Delay Seconds')
        l8.pack()
        self.e7 = Entry(self)
        self.e7.pack(fill='x')
        self.e7.focus_set()
        self.b = Button(self, text='Send Messages')
        self.b.bind('<Button>', lambda e: self.send_message(self.e8.get(), self.e9.get(), self.e10.get(), self.e11.get(), self.e12.get(), self.e.get(), self.e1.get(), self.e2.get(), self.e3.get(), self.e4.get(), self.e5.get(), self.e6.get(),self.e7.get()))
        self.b.pack(side='bottom', pady=10)
        self.mainloop()        

def copydata():
    NewWindow1(root)


root = Tk()
root.title('Telegram Send Chat Bot')
b = Button(root, text='Load Program', width=100, command=copydata)
b.pack(side='bottom', pady=10)
root.mainloop()

# %%
from telethon.sync import TelegramClient, events

# %%
api_id = 8334330
api_hash = "8c659b1ba125cca04156f1bc31449051"

# %%
client = TelegramClient("Telegram Chat Bot", api_id, api_hash)

# %%
await client.connect()
client.is_connected()

# %%
await client.start()
